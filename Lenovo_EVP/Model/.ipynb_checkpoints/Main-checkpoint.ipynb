# %%
# get phrase
def filter_word(company,word):
    import pandas as pd
    import numpy as np
    file = 'Phrase/'+company+'_phrase.csv'
    df=pd.read_csv(file,index_col=0)
    pro=[]; con=[]
    for i in range(len(df['pro'])):
        if type(df['pro'][i])==str:
            pro.append(df['pro'][i].lower())
    for i in range(len(df['con'])):
        if type(df['con'][i])==str:
            con.append(df['con'][i].lower())
    pro_list=list(set(list(filter(lambda x: word in x and len(x.split())>1, pro))))
    con_list=list(set(list(filter(lambda x: word in x and len(x.split())>1, con))))
    col_pro = word+'_pro'
    col_con = word+'_con'
    df1=pd.DataFrame(pro_list,columns=[col_pro])
    df2=pd.DataFrame(con_list,columns=[col_con])
    result = pd.concat([df1,df2],axis=1)
    return result

# %%
#get review
def filter_review(company,word,p_number,n_number):
    import pandas as pd
    import numpy as np
    file = 'reviews/'+company+'.csv'
    df=pd.read_csv(file,index_col=0)
    df_p=df[df['Pros'].apply(lambda x: word in x) ==True].iloc[:p_number]
    df_n=df[df['Cons'].apply(lambda x: word in x) ==True].iloc[:n_number]
    
    return df_p,df_n

# %%
# get sentiment
def get_affect(company,word,lower=True):
    import nltk
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
    import pandas as pd
    import numpy as np
    content = pd.read_csv('reviews/'+company+'.csv',index_col=0)
    full_review = ''
    for review in content['Pros']:
        full_review = full_review+review+' '
    for review in content['Cons']:
        full_review = full_review+review+' '
        
    analyzer = SentimentIntensityAnalyzer()
    sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
    sentences = sent_detector.tokenize(full_review.strip())
    sentence_count = 0
    running_total = 0
    for sentence in sentences:
        if lower: 
            sentence = sentence.lower()
            word = word.lower()
        if word in sentence:
            vs = analyzer.polarity_scores(sentence) 
            running_total += vs['compound']
            sentence_count += 1
    if sentence_count == 0: return 0
    return running_total/sentence_count

# %%
def __main__():
    import pandas as pd
    import numpy as np
    from tabulate import tabulate
    from IPython.display import display
    
    company = input("Which company? ").lower()
    print()
    company_list=['apple','microsoft','alibaba','baidu','dell','hp','huawei','ibm','lenovo','samsung']
    if company not in company_list:
        print("Please check the company name. The company should be in ['Apple','Microsoft','Alibaba','Baidu','Dell','Hp','Huawei','IBM','Lenovo','Samsung']")
        company = input("Which company? ").lower()
        
    word = input("Input your word: ").lower()
    print()
    p_reviews = input("How many positive reviews related to the word inputted you want (default 10)")
    n_reviews = input("How many negative reviews related to the word inputted you want (default 10)")
    phrases = input("How many phrases related to the word inputted you want (default 10)")
    print()
    try:
        p_reviews = int(p_reviews)
    except:
        p_reviews = 10
    try:
        n_reviews = int(n_reviews)
    except:
        n_reviews = 10
    try:
        phrases = int(phrases)
    except:
        phrases = 10
    
    sentiment = get_affect(company,word)
    phrase_result = filter_word(company,word).iloc[:phrases]
    positive_review, negative_review = filter_review(company,word,p_reviews,n_reviews)
    print("The sentiment score for this word is: " + str(sentiment))
    print()
    print("Phrase results are: ")
    print(tabulate(phrase_result, headers='keys', tablefmt='psql'))
    print("Positive reviews are: ")
    display(positive_review)
    print("Negative reviews are: ")
    display(negative_review)
    return sentiment, phrase_result, positive_review, negative_review

# %%
sentiment, phrase_result, positive_review, negative_review = __main__()
# Out:
# Which company? huawei
#
# Input your word: salary
#
# How many positive reviews related to the word inputted you want (default 10)
# How many negative reviews related to the word inputted you want (default 10)
# How many phrases related to the word inputted you want (default 10)
#
# The sentiment score for this word is: 0.5297526315789475
#
# Phrase results are:
# +----+----------------------+-------------------+
# |    | salary_pro           | salary_con        |
# |----+----------------------+-------------------|
# |  0 | high start salary    | no salary reviews |
# |  1 | the salary           | nan               |
# |  2 | the average salary   | nan               |
# |  3 | decent salary        | nan               |
# |  4 | good salary          | nan               |
# |  5 | initial salary       | nan               |
# |  6 | high salary          | nan               |
# |  7 | good starting salary | nan               |
# |  8 | base salary          | nan               |
# +----+----------------------+-------------------+
# Positive reviews are:
#                                         Title  \
# 16                      "Huawei Technologies"
# 25                     "good company overall"
# 31                                "Walk away"
# 32                           "Solution Sales"
# 34      "good company but lots of work to do"
# 35                   "Horrible place to work"
# 39  "Good pay but poor management/leadership"
# 40                           "Work at Huawei"
# 59                                  "Analyst"
# 68                   "Huawei France Overview"
#
#                                              WorkTime  \
# 16  I have been working at Huawei Technologies ful...
# 25  I have been working at Huawei Technologies ful...
# 31          I worked at Huawei Technologies full-time
# 32          I worked at Huawei Technologies full-time
# 34          I worked at Huawei Technologies full-time
# 35  I have been working at Huawei Technologies ful...
# 39  I worked at Huawei Technologies full-time for ...
# 40  I worked at Huawei Technologies full-time for ...
# 59          I worked at Huawei Technologies part-time
# 68  I have been working at Huawei Technologies ful...
#
#                                                  Pros  \
# 16  Salary is good, much higher than the average s...
# 25  the whole package includes salary, bonus and T...
# 31                 salary was fair and benefits fair.
# 32               Decent amount of salary and benefits
# 34  high start salary in China, long term high salary
# 35  The only pro is they pay much higher than most...
# 39                      Great comp package and salary
# 40  The salary is good.\r\nMany promotion opportun...
# 59  Good salary and good opportunity and boss is nice
# 68  Good company culture, transparent management, ...
#
#                                                  Cons  Work/Life Balance  \
# 16       No work life balance, people work hard here.                1.0
# 25  limited positions in USA, unless transferred t...                3.0
# 31  Culture was awful; information available to em...                NaN
# 32            Work-life balance does not really exist                NaN
# 34       need to work overload and come home at night                3.0
# 35  -Gave me very little information before joinin...                3.0
# 39  Poor performers hired as local senior managers...                4.0
# 40                work life balance is not very good.                2.0
# 59          Intensified working time and tedious work                4.0
# 68  Challenges from telecommunication industry, lo...                5.0
#
#     Culture & Values  Career Opportunities  Compensation & Benefits  \
# 16               4.0                   4.0                      4.0
# 25               4.0                   4.0                      4.0
# 31               NaN                   NaN                      NaN
# 32               NaN                   NaN                      NaN
# 34               4.0                   5.0                      5.0
# 35               1.0                   1.0                      3.0
# 39               3.0                   3.0                      5.0
# 40               3.0                   4.0                      4.0
# 59               4.0                   4.0                      4.0
# 68               5.0                   5.0                      5.0
#
#     Senior Management
# 16                4.0
# 25                4.0
# 31                NaN
# 32                NaN
# 34                5.0
# 35                1.0
# 39                1.0
# 40                3.0
# 59                4.0
# 68                5.0
# Negative reviews are:
#                                                  Title  \
# 48                               "Operations Director"
# 106  "Mostly positive but room for improvement (for...
# 154                                            "Goood"
#
#                                               WorkTime  \
# 48   I have been working at Huawei Technologies ful...
# 106          I worked at Huawei Technologies full-time
# 154          I worked at Huawei Technologies full-time
#
#                                                   Pros  \
# 48    Great place to learn. Graet for recent graduates
# 106  -Structured projects, driven work force\r\n-go...
# 154  good salary, working condition, and friendly p...
#
#                                                   Cons  Work/Life Balance  \
# 48   No professional growth if you are not chinese,...                1.0
# 106  -low amount of facilities (company cars not av...                3.0
# 154             Very good salary. Good to start career                4.0
#
#      Culture & Values  Career Opportunities  Compensation & Benefits  \
# 48                3.0                   1.0                      3.0
# 106               4.0                   4.0                      2.0
# 154               4.0                   4.0                      4.0
#
#      Senior Management
# 48                 1.0
# 106                3.0
# 154                4.0

# %%
positive_review.iloc[0]['Pros']
# Out:
# 'Best place to work, with amazing compensation and benefits'

# %%
positive_review.iloc[0]['Cons']
# Out:
# 'You become very comfortable and will feel difficult to move out.'

# %%
company_list=['apple','microsoft','alibaba','baidu','dell','hp','huawei','ibm','lenovo','samsung']
word_list = ['compensation', 'pay', 'salary', 'money', 'wage', 'promotion','bonus','fair']
result = list()
for company in company_list:
    for word in word_list:
        sentiment = get_affect(company,word)
        result.append({'name': company, 'word':word, 'sentiment_score':sentiment})

# %%
result
# Out:
# [{'name': 'apple',
#   'word': 'compensation',
#   'sentiment_score': 0.5245805555555555},
#  {'name': 'apple', 'word': 'pay', 'sentiment_score': 0.4886993913043467},
#  {'name': 'apple', 'word': 'salary', 'sentiment_score': 0.5478560240963856},
#  {'name': 'apple', 'word': 'money', 'sentiment_score': 0.33799047619047634},
#  {'name': 'apple', 'word': 'wage', 'sentiment_score': 0.33436666666666665},
#  {'name': 'apple', 'word': 'promotion', 'sentiment_score': 0.1665602272727273},
#  {'name': 'apple', 'word': 'bonus', 'sentiment_score': 0.6111166666666668},
#  {'name': 'apple', 'word': 'fair', 'sentiment_score': 0.3006693333333332},
#  {'name': 'microsoft',
#   'word': 'compensation',
#   'sentiment_score': 0.4906073770491802},
#  {'name': 'microsoft', 'word': 'pay', 'sentiment_score': 0.5021680656934296},
#  {'name': 'microsoft',
#   'word': 'salary',
#   'sentiment_score': 0.4919508695652172},
#  {'name': 'microsoft', 'word': 'money', 'sentiment_score': 0.2793050847457628},
#  {'name': 'microsoft', 'word': 'wage', 'sentiment_score': 0.2755142857142857},
#  {'name': 'microsoft',
#   'word': 'promotion',
#   'sentiment_score': 0.0773102272727273},
#  {'name': 'microsoft', 'word': 'bonus', 'sentiment_score': 0.6126526315789476},
#  {'name': 'microsoft', 'word': 'fair', 'sentiment_score': 0.34947741935483867},
#  {'name': 'alibaba', 'word': 'compensation', 'sentiment_score': 0.9804},
#  {'name': 'alibaba', 'word': 'pay', 'sentiment_score': 0.1277},
#  {'name': 'alibaba', 'word': 'salary', 'sentiment_score': 0.5284428571428571},
#  {'name': 'alibaba', 'word': 'money', 'sentiment_score': 0},
#  {'name': 'alibaba', 'word': 'wage', 'sentiment_score': 0},
#  {'name': 'alibaba', 'word': 'promotion', 'sentiment_score': 0.9719},
#  {'name': 'alibaba', 'word': 'bonus', 'sentiment_score': -0.6187},
#  {'name': 'alibaba', 'word': 'fair', 'sentiment_score': 0},
#  {'name': 'baidu', 'word': 'compensation', 'sentiment_score': 0.5563},
#  {'name': 'baidu', 'word': 'pay', 'sentiment_score': 0.41346666666666665},
#  {'name': 'baidu', 'word': 'salary', 'sentiment_score': 0.9873000000000001},
#  {'name': 'baidu', 'word': 'money', 'sentiment_score': 0},
#  {'name': 'baidu', 'word': 'wage', 'sentiment_score': 0},
#  {'name': 'baidu', 'word': 'promotion', 'sentiment_score': 0},
#  {'name': 'baidu', 'word': 'bonus', 'sentiment_score': 0.7506},
#  {'name': 'baidu', 'word': 'fair', 'sentiment_score': 0},
#  {'name': 'dell',
#   'word': 'compensation',
#   'sentiment_score': 0.35076557377049156},
#  {'name': 'dell', 'word': 'pay', 'sentiment_score': 0.37916509900990075},
#  {'name': 'dell', 'word': 'salary', 'sentiment_score': 0.4531873333333331},
#  {'name': 'dell', 'word': 'money', 'sentiment_score': 0.2796122448979592},
#  {'name': 'dell', 'word': 'wage', 'sentiment_score': 0.6582250000000001},
#  {'name': 'dell', 'word': 'promotion', 'sentiment_score': 0.13428987341772156},
#  {'name': 'dell', 'word': 'bonus', 'sentiment_score': 0.5959722222222225},
#  {'name': 'dell', 'word': 'fair', 'sentiment_score': 0.4897672727272727},
#  {'name': 'hp', 'word': 'compensation', 'sentiment_score': 0.2822},
#  {'name': 'hp', 'word': 'pay', 'sentiment_score': 0.18856879999999995},
#  {'name': 'hp', 'word': 'salary', 'sentiment_score': 0.40700784313725497},
#  {'name': 'hp', 'word': 'money', 'sentiment_score': 0.52883125},
#  {'name': 'hp', 'word': 'wage', 'sentiment_score': 0.40517500000000006},
#  {'name': 'hp', 'word': 'promotion', 'sentiment_score': -0.03655499999999999},
#  {'name': 'hp', 'word': 'bonus', 'sentiment_score': 0.38337407407407414},
#  {'name': 'hp', 'word': 'fair', 'sentiment_score': 0.42753333333333343},
#  {'name': 'huawei', 'word': 'compensation', 'sentiment_score': 0.76224},
#  {'name': 'huawei', 'word': 'pay', 'sentiment_score': 0.530609375},
#  {'name': 'huawei', 'word': 'salary', 'sentiment_score': 0.5297526315789475},
#  {'name': 'huawei', 'word': 'money', 'sentiment_score': 0},
#  {'name': 'huawei', 'word': 'wage', 'sentiment_score': 0},
#  {'name': 'huawei', 'word': 'promotion', 'sentiment_score': -0.047525},
#  {'name': 'huawei', 'word': 'bonus', 'sentiment_score': 0.6457222222222223},
#  {'name': 'huawei', 'word': 'fair', 'sentiment_score': 0.45554999999999995},
#  {'name': 'ibm',
#   'word': 'compensation',
#   'sentiment_score': 0.23639563318777296},
#  {'name': 'ibm', 'word': 'pay', 'sentiment_score': 0.2597549107142842},
#  {'name': 'ibm', 'word': 'salary', 'sentiment_score': 0.29052572463768145},
#  {'name': 'ibm', 'word': 'money', 'sentiment_score': 0.2060725490196078},
#  {'name': 'ibm', 'word': 'wage', 'sentiment_score': 0.0904736842105263},
#  {'name': 'ibm', 'word': 'promotion', 'sentiment_score': -0.01886918604651164},
#  {'name': 'ibm', 'word': 'bonus', 'sentiment_score': 0.35252987804878055},
#  {'name': 'ibm', 'word': 'fair', 'sentiment_score': 0.3650037500000001},
#  {'name': 'lenovo', 'word': 'compensation', 'sentiment_score': 0.5184},
#  {'name': 'lenovo', 'word': 'pay', 'sentiment_score': 0.4126538461538463},
#  {'name': 'lenovo', 'word': 'salary', 'sentiment_score': 0.33928095238095235},
#  {'name': 'lenovo', 'word': 'money', 'sentiment_score': -0.11132222222222223},
#  {'name': 'lenovo', 'word': 'wage', 'sentiment_score': -0.67125},
#  {'name': 'lenovo',
#   'word': 'promotion',
#   'sentiment_score': 0.22287999999999997},
#  {'name': 'lenovo', 'word': 'bonus', 'sentiment_score': 0.5736739130434781},
#  {'name': 'lenovo', 'word': 'fair', 'sentiment_score': 0.18830999999999998},
#  {'name': 'samsung',
#   'word': 'compensation',
#   'sentiment_score': 0.6962058823529413},
#  {'name': 'samsung', 'word': 'pay', 'sentiment_score': 0.5982203389830514},
#  {'name': 'samsung', 'word': 'salary', 'sentiment_score': 0.532661111111111},
#  {'name': 'samsung', 'word': 'money', 'sentiment_score': -0.05275000000000002},
#  {'name': 'samsung', 'word': 'wage', 'sentiment_score': 0.9687},
#  {'name': 'samsung',
#   'word': 'promotion',
#   'sentiment_score': 0.40969999999999995},
#  {'name': 'samsung', 'word': 'bonus', 'sentiment_score': 0.8629},
#  {'name': 'samsung', 'word': 'fair', 'sentiment_score': 0.15509999999999996}]

# %%
import csv
csv_file = "compensation.csv"
csv_columns = ['name','word','sentiment_score']
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in result:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %%
result[0]['name']
# Out:
# 'apple'
